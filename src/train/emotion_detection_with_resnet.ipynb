# %%
# !unzip '/home/labuser/Joy/emotion-recognition/datasets/emotion detection.zip' -d '/home/labuser/Joy/emotion-recognition/datasets/data'

# %%
import torch
from torch import nn
from torchvision.models.resnet import resnet18, ResNet18_Weights
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torchvision.transforms.v2 as T
from tqdm import tqdm
from torch import optim
from torch.nn import functional as F

# %% [markdown]
# ## Prepare Dataloader

# %%
transforms = ResNet18_Weights.IMAGENET1K_V1.transforms()
transforms
# Out:
# ImageClassification(
#     crop_size=[224]
#     resize_size=[256]
#     mean=[0.485, 0.456, 0.406]
#     std=[0.229, 0.224, 0.225]
#     interpolation=InterpolationMode.BILINEAR
# )

# %%
train_dir = '/home/labuser/Joy/emotion-recognition/datasets/data/train'
test_dir = '/home/labuser/Joy/emotion-recognition/datasets/data/valid'

# For train
train_dataset = ImageFolder(train_dir, transforms)
train_loader = DataLoader(
    train_dataset,
    batch_size=128,
    shuffle=True,
    pin_memory=True,
    persistent_workers=True,
    num_workers=2
)

# For test
test_dataset = ImageFolder(test_dir, transforms)
test_loader = DataLoader(
    test_dataset,
    batch_size=256,
    shuffle=False,
    pin_memory=True,
    persistent_workers=True,
    num_workers=1
)

# %% [markdown]
# ## Prepare Model

# %%
class ResNet(nn.Module):
  def __init__(self, num_classes):
    super().__init__()

    self.model = resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)

    ## Freeze all the layer
    # for param in list(self.model.parameters())[:20]:
    #   param.requires_grad = False

    ## Modify the classification layer
    in_features = self.model.fc.in_features
    self.model.fc = nn.Linear(in_features, num_classes)

  def forward(self, x):
    x = self.model(x)
    return x

# %% [markdown]
# ## Loss function and optimizers

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
train_dataset.classes
# Out:
# ['angry',
#  'confused',
#  'disgust',
#  'fear',
#  'happy',
#  'neutral',
#  'sad',
#  'shy',
#  'surprise']

# %%
num_classes = len(train_dataset.classes)
model = ResNet(num_classes).to(device)

# %%
# Loss function & optimizer
criterion = nn.CrossEntropyLoss()
params = [param for param in model.parameters() if param.requires_grad]
optimizer = optim.Adam(params, lr=0.001)

# %% [markdown]
# ## Training Loop

# %%
epochs = 100
min_acc = 0

for epoch in range(epochs):
  model.train()
  running_loss = 0.0
  correct_t, total_t = 0, 0

  for images, targets in tqdm(train_loader, desc=f'Training [{epoch + 1}/{epochs}]: '):
    images, targets = images.to(device), targets.to(device)

    optimizer.zero_grad()
    outputs = model(images)
    losses = criterion(outputs, targets)
    losses.backward()
    optimizer.step()

    pred = torch.argmax(outputs, dim=1)
    correct_t += (targets == pred).sum().item()
    total_t += len(train_loader)
    running_loss += losses.item()
  t_loss = running_loss / targets.size(0)
  t_acc = 100 * correct_t / total_t
  print(f'Train losses: {t_loss:.5f}, Train accuracy: {t_acc:.2f}%')

  ## Validation test
  correct_e, total_e = 0, 0
  model.eval()

  for images, targets in tqdm(test_loader, desc='Validation...'):
    images, targets = images.to(device), targets.to(device)

    with torch.no_grad():
      outputs = model(images)
      predictions = torch.argmax(outputs, dim=1)
    total_e += targets.size(0)
    correct_e += sum(predictions == targets).item()
  acc = 100.0 * correct_e / total_e
  print(f'Model accuracy on testing: {acc:.2f}%\n')

  # Save best model
  if (acc > min_acc):
    best_model = f'/home/labuser/Joy/emotion-recognition/src/models/resnet-best-full.pth'
    torch.save({
        'classes': train_dataset.classes,
        'model_state_dict': model.state_dict(),
        'epochs': epoch
    }, best_model)
    min_acc = acc
  
  # Save the last model
  model_path = f'/home/labuser/Joy/emotion-recognition/src/models/resnet-last-model.pth'
  torch.save({
      'classes': train_dataset.classes,
      'model_state_dict': model.state_dict(),
      'epochs': epoch
  }, model_path)

print(f'Train was completed successfully')
# Out:
# Training [1/100]: 100%|██████████| 163/163 [00:36<00:00,  4.52it/s]
# Train losses: 130.34174, Train accuracy: 33.28%
# Validation...: 100%|██████████| 8/8 [00:07<00:00,  1.04it/s]
# Model accuracy on testing: 50.19%
# Training [2/100]: 100%|██████████| 163/163 [00:34<00:00,  4.72it/s]
# Train losses: 105.70075, Train accuracy: 42.40%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.71it/s]
# Model accuracy on testing: 44.72%
# Training [3/100]: 100%|██████████| 163/163 [00:33<00:00,  4.81it/s]
# Train losses: 90.23278, Train accuracy: 47.45%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.44it/s]
# Model accuracy on testing: 51.18%
# Training [4/100]: 100%|██████████| 163/163 [00:33<00:00,  4.83it/s]
# Train losses: 69.37478, Train accuracy: 54.50%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.65it/s]
# Model accuracy on testing: 46.52%
# Training [5/100]: 100%|██████████| 163/163 [00:32<00:00,  5.07it/s]
# Train losses: 53.31283, Train accuracy: 60.12%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.69it/s]
# Model accuracy on testing: 47.62%
# Training [6/100]: 100%|██████████| 163/163 [00:34<00:00,  4.77it/s]
# Train losses: 36.16912, Train accuracy: 66.04%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.64it/s]
# Model accuracy on testing: 52.76%
# Training [7/100]: 100%|██████████| 163/163 [00:33<00:00,  4.84it/s]
# Train losses: 17.37775, Train accuracy: 72.51%
# Validation...: 100%|██████████| 8/8 [00:07<00:00,  1.04it/s]
# Model accuracy on testing: 56.16%
# Training [8/100]: 100%|██████████| 163/163 [00:34<00:00,  4.78it/s]
# Train losses: 10.26486, Train accuracy: 74.85%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.63it/s]
# Model accuracy on testing: 50.96%
# Training [9/100]: 100%|██████████| 163/163 [00:33<00:00,  4.83it/s]
# Train losses: 18.00609, Train accuracy: 72.40%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.80it/s]
# Model accuracy on testing: 53.48%
# Training [10/100]: 100%|██████████| 163/163 [00:33<00:00,  4.89it/s]
# Train losses: 4.69713, Train accuracy: 76.71%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.69it/s]
# Model accuracy on testing: 54.95%
# Training [11/100]: 100%|██████████| 163/163 [00:32<00:00,  5.06it/s]
# Train losses: 2.55077, Train accuracy: 77.49%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.79it/s]
# Model accuracy on testing: 53.64%
# Training [12/100]: 100%|██████████| 163/163 [00:32<00:00,  4.95it/s]
# Train losses: 23.29156, Train accuracy: 70.70%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.80it/s]
# Model accuracy on testing: 50.08%
# Training [13/100]: 100%|██████████| 163/163 [00:33<00:00,  4.93it/s]
# Train losses: 9.95769, Train accuracy: 75.11%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.76it/s]
# Model accuracy on testing: 54.63%
# Training [14/100]: 100%|██████████| 163/163 [00:33<00:00,  4.90it/s]
# Train losses: 14.94292, Train accuracy: 73.88%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.80it/s]
# Model accuracy on testing: 51.23%
# Training [15/100]: 100%|██████████| 163/163 [00:33<00:00,  4.81it/s]
# Train losses: 19.47091, Train accuracy: 72.71%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.82it/s]
# Model accuracy on testing: 52.93%
# Training [16/100]: 100%|██████████| 163/163 [00:33<00:00,  4.92it/s]
# Train losses: 32.31266, Train accuracy: 68.35%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.77it/s]
# Model accuracy on testing: 55.88%
# Training [17/100]: 100%|██████████| 163/163 [00:32<00:00,  4.98it/s]
# Train losses: 5.56278, Train accuracy: 76.54%
# Validation...: 100%|██████████| 8/8 [00:06<00:00,  1.14it/s]
# Model accuracy on testing: 56.81%
# Training [18/100]: 100%|██████████| 163/163 [00:30<00:00,  5.32it/s]
# Train losses: 0.80780, Train accuracy: 77.98%
# Validation...: 100%|██████████| 8/8 [00:07<00:00,  1.11it/s]
# Model accuracy on testing: 53.09%
# Training [19/100]: 100%|██████████| 163/163 [00:32<00:00,  4.97it/s]
# Train losses: 8.42071, Train accuracy: 75.77%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.71it/s]
# Model accuracy on testing: 54.84%
# Training [20/100]: 100%|██████████| 163/163 [00:32<00:00,  5.00it/s]
# Train losses: 14.03649, Train accuracy: 74.05%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.77it/s]
# Model accuracy on testing: 53.80%
# Training [21/100]: 100%|██████████| 163/163 [00:32<00:00,  5.05it/s]
# Train losses: 2.21278, Train accuracy: 77.50%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.82it/s]
# Model accuracy on testing: 54.13%
# Training [22/100]: 100%|██████████| 163/163 [00:32<00:00,  4.97it/s]
# Train losses: 1.49700, Train accuracy: 77.69%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.75it/s]
# Model accuracy on testing: 56.16%
# Training [23/100]: 100%|██████████| 163/163 [00:33<00:00,  4.93it/s]
# Train losses: 3.58738, Train accuracy: 77.36%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.80it/s]
# Model accuracy on testing: 53.31%
# Training [24/100]: 100%|██████████| 163/163 [00:32<00:00,  4.97it/s]
# Train losses: 9.17734, Train accuracy: 75.27%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.75it/s]
# Model accuracy on testing: 52.33%
# Training [25/100]: 100%|██████████| 163/163 [00:32<00:00,  5.07it/s]
# Train losses: 3.02251, Train accuracy: 77.16%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.79it/s]
# Model accuracy on testing: 55.39%
# Training [26/100]: 100%|██████████| 163/163 [00:33<00:00,  4.89it/s]
# Train losses: 0.98721, Train accuracy: 77.81%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.74it/s]
# Model accuracy on testing: 56.10%
# Training [27/100]: 100%|██████████| 163/163 [00:32<00:00,  5.04it/s]
# Train losses: 2.25353, Train accuracy: 77.49%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.73it/s]
# Model accuracy on testing: 57.69%
# Training [28/100]: 100%|██████████| 163/163 [00:33<00:00,  4.89it/s]
# Train losses: 1.33558, Train accuracy: 77.66%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.74it/s]
# Model accuracy on testing: 55.88%
# Training [29/100]: 100%|██████████| 163/163 [00:32<00:00,  4.99it/s]
# Train losses: 0.33561, Train accuracy: 77.97%
# Validation...: 100%|██████████| 8/8 [00:06<00:00,  1.15it/s]
# Model accuracy on testing: 54.84%
# Training [30/100]: 100%|██████████| 163/163 [00:30<00:00,  5.33it/s]
# Train losses: 0.13263, Train accuracy: 78.04%
# Validation...: 100%|██████████| 8/8 [00:06<00:00,  1.14it/s]
# Model accuracy on testing: 56.65%
# Training [31/100]: 100%|██████████| 163/163 [00:33<00:00,  4.85it/s]
# Train losses: 3.60168, Train accuracy: 77.55%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.76it/s]
# Model accuracy on testing: 51.34%
# Training [32/100]: 100%|██████████| 163/163 [00:33<00:00,  4.91it/s]
# Train losses: 38.24824, Train accuracy: 68.37%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.80it/s]
# Model accuracy on testing: 53.09%
# Training [33/100]: 100%|██████████| 163/163 [00:33<00:00,  4.90it/s]
# Train losses: 8.51332, Train accuracy: 75.58%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.79it/s]
# Model accuracy on testing: 54.13%
# Training [34/100]: 100%|██████████| 163/163 [00:32<00:00,  5.00it/s]
# Train losses: 0.85309, Train accuracy: 77.95%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.76it/s]
# Model accuracy on testing: 55.50%
# Training [35/100]: 100%|██████████| 163/163 [00:32<00:00,  4.95it/s]
# Train losses: 7.25086, Train accuracy: 76.68%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.79it/s]
# Model accuracy on testing: 51.29%
# Training [36/100]: 100%|██████████| 163/163 [00:33<00:00,  4.88it/s]
# Train losses: 21.61955, Train accuracy: 72.82%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.74it/s]
# Model accuracy on testing: 52.44%
# Training [37/100]: 100%|██████████| 163/163 [00:33<00:00,  4.82it/s]
# Train losses: 6.80496, Train accuracy: 76.03%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.79it/s]
# Model accuracy on testing: 52.27%
# Training [38/100]: 100%|██████████| 163/163 [00:33<00:00,  4.87it/s]
# Train losses: 11.41537, Train accuracy: 75.27%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.78it/s]
# Model accuracy on testing: 54.84%
# Training [39/100]: 100%|██████████| 163/163 [00:33<00:00,  4.89it/s]
# Train losses: 10.59124, Train accuracy: 75.03%
# Validation...: 100%|██████████| 8/8 [00:06<00:00,  1.16it/s]
# Model accuracy on testing: 54.02%
# Training [40/100]: 100%|██████████| 163/163 [00:30<00:00,  5.32it/s]
# Train losses: 6.03516, Train accuracy: 76.49%
# Validation...: 100%|██████████| 8/8 [00:06<00:00,  1.15it/s]
# Model accuracy on testing: 55.56%
# Training [41/100]: 100%|██████████| 163/163 [00:33<00:00,  4.92it/s]
# Train losses: 4.90012, Train accuracy: 76.92%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.82it/s]
# Model accuracy on testing: 53.91%
# Training [42/100]: 100%|██████████| 163/163 [00:33<00:00,  4.89it/s]
# Train losses: 11.71643, Train accuracy: 74.87%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.75it/s]
# Model accuracy on testing: 53.64%
# Training [43/100]: 100%|██████████| 163/163 [00:32<00:00,  4.99it/s]
# Train losses: 2.95614, Train accuracy: 77.47%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.76it/s]
# Model accuracy on testing: 53.04%
# Training [44/100]: 100%|██████████| 163/163 [00:33<00:00,  4.88it/s]
# Train losses: 11.29557, Train accuracy: 75.08%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.85it/s]
# Model accuracy on testing: 54.30%
# Training [45/100]: 100%|██████████| 163/163 [00:33<00:00,  4.80it/s]
# Train losses: 0.84173, Train accuracy: 77.88%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.74it/s]
# Model accuracy on testing: 55.17%
# Training [46/100]: 100%|██████████| 163/163 [00:31<00:00,  5.13it/s]
# Train losses: 0.73347, Train accuracy: 78.03%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.91it/s]
# Model accuracy on testing: 54.63%
# Training [47/100]: 100%|██████████| 163/163 [00:34<00:00,  4.71it/s]
# Train losses: 7.05146, Train accuracy: 76.28%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.80it/s]
# Model accuracy on testing: 52.98%
# Training [48/100]: 100%|██████████| 163/163 [00:31<00:00,  5.17it/s]
# Train losses: 0.94331, Train accuracy: 77.94%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.81it/s]
# Model accuracy on testing: 54.30%
# Training [49/100]: 100%|██████████| 163/163 [00:34<00:00,  4.78it/s]
# Train losses: 5.55838, Train accuracy: 76.54%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.85it/s]
# Model accuracy on testing: 53.20%
# Training [50/100]: 100%|██████████| 163/163 [00:32<00:00,  4.95it/s]
# Train losses: 2.90147, Train accuracy: 77.78%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.82it/s]
# Model accuracy on testing: 52.11%
# Training [51/100]: 100%|██████████| 163/163 [00:33<00:00,  4.87it/s]
# Train losses: 13.57762, Train accuracy: 74.52%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.85it/s]
# Model accuracy on testing: 53.26%
# Training [52/100]: 100%|██████████| 163/163 [00:33<00:00,  4.88it/s]
# Train losses: 5.54013, Train accuracy: 76.54%
# Validation...: 100%|██████████| 8/8 [00:08<00:00,  1.00s/it]
# Model accuracy on testing: 54.46%
# Training [53/100]: 100%|██████████| 163/163 [00:29<00:00,  5.45it/s]
# Train losses: 1.38163, Train accuracy: 77.98%
# Validation...: 100%|██████████| 8/8 [00:07<00:00,  1.08it/s]
# Model accuracy on testing: 53.97%
# Training [54/100]: 100%|██████████| 163/163 [00:32<00:00,  4.99it/s]
# Train losses: 10.97983, Train accuracy: 74.97%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.77it/s]
# Model accuracy on testing: 52.27%
# Training [55/100]: 100%|██████████| 163/163 [00:32<00:00,  4.95it/s]
# Train losses: 0.83582, Train accuracy: 77.88%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.85it/s]
# Model accuracy on testing: 55.06%
# Training [56/100]: 100%|██████████| 163/163 [00:33<00:00,  4.92it/s]
# Train losses: 0.48053, Train accuracy: 77.94%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.78it/s]
# Model accuracy on testing: 55.01%
# Training [57/100]: 100%|██████████| 163/163 [00:32<00:00,  5.01it/s]
# Train losses: 0.42126, Train accuracy: 78.03%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.80it/s]
# Model accuracy on testing: 52.93%
# Training [58/100]: 100%|██████████| 163/163 [00:32<00:00,  4.98it/s]
# Train losses: 5.48781, Train accuracy: 76.83%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.77it/s]
# Model accuracy on testing: 52.49%
# Training [59/100]: 100%|██████████| 163/163 [00:33<00:00,  4.89it/s]
# Train losses: 16.23135, Train accuracy: 73.60%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.75it/s]
# Model accuracy on testing: 52.38%
# Training [60/100]: 100%|██████████| 163/163 [00:34<00:00,  4.79it/s]
# Train losses: 8.17720, Train accuracy: 76.25%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.75it/s]
# Model accuracy on testing: 53.09%
# Training [61/100]: 100%|██████████| 163/163 [00:33<00:00,  4.86it/s]
# Train losses: 9.99596, Train accuracy: 75.38%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.81it/s]
# Model accuracy on testing: 53.09%
# Training [62/100]: 100%|██████████| 163/163 [00:33<00:00,  4.91it/s]
# Train losses: 3.20461, Train accuracy: 77.88%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.81it/s]
# Model accuracy on testing: 54.08%
# Training [63/100]: 100%|██████████| 163/163 [00:33<00:00,  4.85it/s]
# Train losses: 7.59876, Train accuracy: 76.71%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.81it/s]
# Model accuracy on testing: 52.49%
# Training [64/100]: 100%|██████████| 163/163 [00:32<00:00,  4.98it/s]
# Train losses: 8.01108, Train accuracy: 76.20%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.87it/s]
# Model accuracy on testing: 54.13%
# Training [65/100]: 100%|██████████| 163/163 [00:33<00:00,  4.81it/s]
# Train losses: 5.25548, Train accuracy: 76.78%
# Validation...: 100%|██████████| 8/8 [00:07<00:00,  1.06it/s]
# Model accuracy on testing: 52.87%
# Training [66/100]: 100%|██████████| 163/163 [00:33<00:00,  4.84it/s]
# Train losses: 3.90040, Train accuracy: 76.94%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.83it/s]
# Model accuracy on testing: 54.19%
# Training [67/100]: 100%|██████████| 163/163 [00:33<00:00,  4.89it/s]
# Train losses: 4.70606, Train accuracy: 77.74%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.80it/s]
# Model accuracy on testing: 54.95%
# Training [68/100]: 100%|██████████| 163/163 [00:33<00:00,  4.82it/s]
# Train losses: 6.25881, Train accuracy: 76.25%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.82it/s]
# Model accuracy on testing: 53.59%
# Training [69/100]: 100%|██████████| 163/163 [00:32<00:00,  4.96it/s]
# Train losses: 2.82210, Train accuracy: 77.67%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.83it/s]
# Model accuracy on testing: 51.51%
# Training [70/100]: 100%|██████████| 163/163 [00:33<00:00,  4.88it/s]
# Train losses: 11.77511, Train accuracy: 74.87%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.81it/s]
# Model accuracy on testing: 54.95%
# Training [71/100]: 100%|██████████| 163/163 [00:33<00:00,  4.90it/s]
# Train losses: 0.90260, Train accuracy: 77.95%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.83it/s]
# Model accuracy on testing: 54.19%
# Training [72/100]: 100%|██████████| 163/163 [00:32<00:00,  4.95it/s]
# Train losses: 4.00665, Train accuracy: 77.14%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.84it/s]
# Model accuracy on testing: 54.35%
# Training [73/100]: 100%|██████████| 163/163 [00:33<00:00,  4.84it/s]
# Train losses: 1.93948, Train accuracy: 78.03%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.86it/s]
# Model accuracy on testing: 54.46%
# Training [74/100]: 100%|██████████| 163/163 [00:33<00:00,  4.91it/s]
# Train losses: 7.14838, Train accuracy: 76.10%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.84it/s]
# Model accuracy on testing: 53.69%
# Training [75/100]: 100%|██████████| 163/163 [00:33<00:00,  4.80it/s]
# Train losses: 1.64191, Train accuracy: 77.99%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.84it/s]
# Model accuracy on testing: 52.65%
# Training [76/100]: 100%|██████████| 163/163 [00:33<00:00,  4.80it/s]
# Train losses: 8.32245, Train accuracy: 76.60%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.81it/s]
# Model accuracy on testing: 53.59%
# Training [77/100]: 100%|██████████| 163/163 [00:33<00:00,  4.86it/s]
# Train losses: 5.91796, Train accuracy: 76.37%
# Validation...: 100%|██████████| 8/8 [00:07<00:00,  1.04it/s]
# Model accuracy on testing: 55.83%
# Training [78/100]: 100%|██████████| 163/163 [00:30<00:00,  5.33it/s]
# Train losses: 0.58473, Train accuracy: 77.94%
# Validation...: 100%|██████████| 8/8 [00:07<00:00,  1.03it/s]
# Model accuracy on testing: 54.73%
# Training [79/100]: 100%|██████████| 163/163 [00:33<00:00,  4.84it/s]
# Train losses: 1.28954, Train accuracy: 77.75%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.78it/s]
# Model accuracy on testing: 53.20%
# Training [80/100]: 100%|██████████| 163/163 [00:33<00:00,  4.93it/s]
# Train losses: 4.54827, Train accuracy: 77.19%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.78it/s]
# Model accuracy on testing: 51.94%
# Training [81/100]: 100%|██████████| 163/163 [00:32<00:00,  4.94it/s]
# Train losses: 5.67923, Train accuracy: 76.63%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.83it/s]
# Model accuracy on testing: 53.42%
# Training [82/100]: 100%|██████████| 163/163 [00:33<00:00,  4.89it/s]
# Train losses: 7.18306, Train accuracy: 76.17%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.81it/s]
# Model accuracy on testing: 52.98%
# Training [83/100]: 100%|██████████| 163/163 [00:33<00:00,  4.80it/s]
# Train losses: 0.80405, Train accuracy: 77.90%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.77it/s]
# Model accuracy on testing: 53.59%
# Training [84/100]: 100%|██████████| 163/163 [00:34<00:00,  4.79it/s]
# Train losses: 7.02047, Train accuracy: 76.89%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.76it/s]
# Model accuracy on testing: 53.75%
# Training [85/100]: 100%|██████████| 163/163 [00:33<00:00,  4.82it/s]
# Train losses: 6.38199, Train accuracy: 76.34%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.89it/s]
# Model accuracy on testing: 51.56%
# Training [86/100]: 100%|██████████| 163/163 [00:32<00:00,  5.00it/s]
# Train losses: 0.67761, Train accuracy: 77.92%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.83it/s]
# Model accuracy on testing: 54.24%
# Training [87/100]: 100%|██████████| 163/163 [00:34<00:00,  4.67it/s]
# Train losses: 0.96443, Train accuracy: 78.03%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.85it/s]
# Model accuracy on testing: 52.49%
# Training [88/100]: 100%|██████████| 163/163 [00:32<00:00,  4.99it/s]
# Train losses: 7.95081, Train accuracy: 76.08%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.77it/s]
# Model accuracy on testing: 54.90%
# Training [89/100]: 100%|██████████| 163/163 [00:33<00:00,  4.94it/s]
# Train losses: 5.31698, Train accuracy: 76.51%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.74it/s]
# Model accuracy on testing: 53.48%
# Training [90/100]: 100%|██████████| 163/163 [00:34<00:00,  4.79it/s]
# Train losses: 0.34129, Train accuracy: 78.00%
# Validation...: 100%|██████████| 8/8 [00:07<00:00,  1.08it/s]
# Model accuracy on testing: 53.37%
# Training [91/100]: 100%|██████████| 163/163 [00:33<00:00,  4.82it/s]
# Train losses: 1.48740, Train accuracy: 78.03%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.86it/s]
# Model accuracy on testing: 53.69%
# Training [92/100]: 100%|██████████| 163/163 [00:34<00:00,  4.77it/s]
# Train losses: 6.87037, Train accuracy: 76.51%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.82it/s]
# Model accuracy on testing: 53.04%
# Training [93/100]: 100%|██████████| 163/163 [00:33<00:00,  4.84it/s]
# Train losses: 8.56598, Train accuracy: 75.70%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.84it/s]
# Model accuracy on testing: 55.39%
# Training [94/100]: 100%|██████████| 163/163 [00:32<00:00,  4.95it/s]
# Train losses: 3.75372, Train accuracy: 77.46%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.87it/s]
# Model accuracy on testing: 54.73%
# Training [95/100]: 100%|██████████| 163/163 [00:33<00:00,  4.90it/s]
# Train losses: 3.33847, Train accuracy: 77.15%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.79it/s]
# Model accuracy on testing: 55.01%
# Training [96/100]: 100%|██████████| 163/163 [00:33<00:00,  4.83it/s]
# Train losses: 0.88730, Train accuracy: 77.88%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.81it/s]
# Model accuracy on testing: 54.63%
# Training [97/100]: 100%|██████████| 163/163 [00:33<00:00,  4.84it/s]
# Train losses: 0.76650, Train accuracy: 78.04%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.86it/s]
# Model accuracy on testing: 54.52%
# Training [98/100]: 100%|██████████| 163/163 [00:33<00:00,  4.89it/s]
# Train losses: 11.19735, Train accuracy: 75.75%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.84it/s]
# Model accuracy on testing: 54.41%
# Training [99/100]: 100%|██████████| 163/163 [00:33<00:00,  4.88it/s]
# Train losses: 13.81923, Train accuracy: 75.24%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.82it/s]
# Model accuracy on testing: 52.76%
# Training [100/100]: 100%|██████████| 163/163 [00:34<00:00,  4.79it/s]
# Train losses: 7.20443, Train accuracy: 76.88%
# Validation...: 100%|██████████| 8/8 [00:04<00:00,  1.79it/s]
# Model accuracy on testing: 51.83%
#
# Train was completed successfully

# %% [markdown]
# ## Model evaluation

# %%
correct, total = 0, 0
model.eval()

for images, targets in tqdm(test_loader, desc=f'Validation...'):
  images, targets = images.to(device), targets.to(device)

  with torch.no_grad():
    outputs = model(images)
    predictions = torch.argmax(outputs, dim=1)
  total += targets.size(0)
  correct += sum(predictions == targets).item()
acc = 100.0 * correct / total
print(f'Model accuracy on testing: {acc:.2f}')
# Out:
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.52it/s]
# Model accuracy on testing: 51.83

# %% [markdown]
# ## Load model & inference

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
model_path = '/home/labuser/Joy/emotion-recognition/src/models/resnet-last-model.pth'
# model_path = '/content/drive/MyDrive/emotion-recognition/models/resnet-best-full.pth'
checkpoint = torch.load(model_path, map_location=device)
classes = checkpoint['classes']
model_state_dict = checkpoint['model_state_dict']

model = ResNet(len(classes)).to(device)
model.load_state_dict(model_state_dict)
checkpoint['epochs']
# Out:
# 99

# %%
from PIL import Image
from torchvision.transforms import v2 as T

# %%
# Infer the model
def predict(image_path, model):
  image = Image.open(image_path).convert('RGB')
  transforms = T.Compose([
      T.ToImage(),
      T.ToDtype(torch.float32, scale=True)
  ])
  image = transforms(image).to(device)

  model.eval()
  with torch.no_grad():
    outputs = model(image.unsqueeze(0))
  predictions = torch.argmax(outputs, dim=1)
  return predictions

# %%
image_path = '/content/face.jpg'
results = predict(image_path, model)
classes[results.item()]
# Out:
# 'happy'

# %%
def predict_with(image_path, model, classes):
  image = Image.open(image_path).convert('RGB')
  # transforms = T.Compose([
  #     T.ToImage(),
  #     T.ToDtype(torch.float32, scale=True),
  #     T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
  # ])

  transforms = ResNet18_Weights.IMAGENET1K_V1.transforms()
  image_batch = transforms(image).to(device).unsqueeze(0)

  model.eval()
  with torch.no_grad():
    outputs = model(image_batch)
  probabilities = F.softmax(outputs[0], dim=0)
  values, id = torch.topk(probabilities, 5)

  pred = {}
  for value, id in zip(values, id):
    pred[classes[id]] = value.item()
  return pred

# %%
# Neutral
image_path = '/content/drive/MyDrive/emotion-recognition/assets/face.jpg'
predict_with(image_path, model, classes)
# Out:
# {'neutral': 0.99979168176651,
#  'surprise': 0.00011066641309298575,
#  'confused': 4.494014865485951e-05,
#  'angry': 2.68292824330274e-05,
#  'happy': 1.7674638002063148e-05}

# %%
# Neutral
image_path = '/content/drive/MyDrive/emotion-recognition/assets/face1.jpg'
predict_with(image_path, model, classes)
# Out:
# {'neutral': 0.9999744892120361,
#  'confused': 1.795478237909265e-05,
#  'surprise': 6.091743671277072e-06,
#  'sad': 1.3594773236036417e-06,
#  'disgust': 9.24924279388506e-08}

# %%
# Sad
image_path = '/content/drive/MyDrive/emotion-recognition/assets/Screenshot 2025-11-12 004551.png'
predict_with(image_path, model, classes)
# Out:
# {'sad': 0.6969957947731018,
#  'neutral': 0.15038418769836426,
#  'confused': 0.07768415659666061,
#  'angry': 0.05305913835763931,
#  'disgust': 0.01241245400160551}

# %%
# Happy
image_path = '/content/drive/MyDrive/emotion-recognition/assets/Screenshot 2025-11-12 004909.png'
predict_with(image_path, model, classes)
# Out:
# {'neutral': 0.9997139573097229,
#  'sad': 0.0002165273472201079,
#  'surprise': 4.868244650424458e-05,
#  'angry': 8.166888619598467e-06,
#  'shy': 5.029511612519855e-06}
