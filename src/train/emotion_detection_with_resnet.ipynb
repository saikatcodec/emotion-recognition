# %%
# !unzip '/home/labuser/Joy/emotion-recognition/datasets/emotion detection.zip' -d '/home/labuser/Joy/emotion-recognition/datasets/data'

# %%
import torch
from torch import nn
from torchvision.models.resnet import resnet50, ResNet50_Weights
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torchvision.transforms.v2 as T
from tqdm import tqdm
from torch import optim
from torch.nn import functional as F
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

# %% [markdown]
# ## Prepare Dataloader

# %%
transforms = ResNet50_Weights.IMAGENET1K_V1.transforms()
transforms
# Out:
# ImageClassification(
#     crop_size=[224]
#     resize_size=[256]
#     mean=[0.485, 0.456, 0.406]
#     std=[0.229, 0.224, 0.225]
#     interpolation=InterpolationMode.BILINEAR
# )

# %%
train_dir = '/home/labuser/Joy/emotion-recognition/datasets/data/train'
test_dir = '/home/labuser/Joy/emotion-recognition/datasets/data/valid'

# For train
train_dataset = ImageFolder(train_dir, transforms)
train_loader = DataLoader(
    train_dataset,
    batch_size=128,
    shuffle=True,
    pin_memory=True,
    persistent_workers=True,
    num_workers=2
)

# For test
test_dataset = ImageFolder(test_dir, transforms)
test_loader = DataLoader(
    test_dataset,
    batch_size=256,
    shuffle=False,
    pin_memory=True,
    persistent_workers=True,
    num_workers=1
)

# %% [markdown]
# ## Prepare Model

# %%
class ResNet(nn.Module):
  def __init__(self, num_classes):
    super().__init__()

    self.model = resnet50(weights=ResNet50_Weights.IMAGENET1K_V1)

    # Freeze first 20th the layer
    for param in list(self.model.parameters())[:10]:
      param.requires_grad = False

    # Freeze the layer
    for param in list(self.model.parameters())[50:60]:
      param.requires_grad = False

    ## Modify the classification layer
    in_features = self.model.fc.in_features
    self.model.fc = nn.Sequential(
      nn.Dropout(0.5, inplace=True),
      nn.Linear(in_features, num_classes)
    )

  def forward(self, x):
    x = self.model(x)
    return x

# %% [markdown]
# ## Loss function and optimizers

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
train_dataset.classes
# Out:
# ['angry',
#  'confused',
#  'disgust',
#  'fear',
#  'happy',
#  'neutral',
#  'sad',
#  'shy',
#  'surprise']

# %%
num_classes = len(train_dataset.classes)
model = ResNet(num_classes).to(device)

# %%
# Calculate class weight
labels = np.array(train_dataset.targets)
class_weight = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(labels),
    y=labels
)

class_weight = torch.tensor(class_weight, device=device, dtype=torch.float32)
class_weight
# Out:
# tensor([0.8735, 1.0512, 0.9889, 1.0278, 1.2688, 0.9158, 1.0097, 1.4330, 0.7400],
#        device='cuda:0')

# %%
# Loss function & optimizer
criterion = nn.CrossEntropyLoss(weight=class_weight)
params = [param for param in model.parameters() if param.requires_grad]
optimizer = optim.Adam(params, lr=0.001, weight_decay=1e-4)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='max',
    factor=0.1,
    patience=2,
    threshold=0.01,
    cooldown=1,
    min_lr=1e-6
)

# %% [markdown]
# ## Training Loop

# %%
epochs = 200
min_acc = 0

for epoch in range(epochs):
  model.train()
  running_loss = 0.0
  correct_t, total_t = 0, 0

  for images, targets in tqdm(train_loader, desc=f'Training [{epoch + 1}/{epochs}]: '):
    images, targets = images.to(device), targets.to(device)

    optimizer.zero_grad()
    outputs = model(images)
    losses = criterion(outputs, targets)
    losses.backward()
    optimizer.step()

    pred = torch.argmax(outputs, dim=1)
    correct_t += (targets == pred).sum().item()
    total_t += targets.size(0)
    running_loss += losses.item()
  t_loss = running_loss / len(train_loader)
  t_acc = 100 * correct_t / total_t
  print(f'Train losses: {t_loss:.5f}, Train accuracy: {t_acc:.2f}%')

  ## Validation test
  correct_e, total_e = 0, 0
  model.eval()

  for images, targets in tqdm(test_loader, desc='Validation...'):
    images, targets = images.to(device), targets.to(device)

    with torch.no_grad():
      outputs = model(images)
      predictions = torch.argmax(outputs, dim=1)
    total_e += targets.size(0)
    correct_e += sum(predictions == targets).item()
  acc = 100.0 * correct_e / total_e
  scheduler.step(acc)
  print(f'Model accuracy on testing: {acc:.2f}%\n')

  # Save best model
  if (acc > min_acc):
    best_model = f'/home/labuser/Joy/emotion-recognition/src/models/resnet-best-full.pth'
    torch.save({
        'classes': train_dataset.classes,
        'model_state_dict': model.state_dict(),
        'epochs': epoch
    }, best_model)
    min_acc = acc
  
  # Save the last model
  model_path = f'/home/labuser/Joy/emotion-recognition/src/models/resnet-last-model.pth'
  torch.save({
      'classes': train_dataset.classes,
      'model_state_dict': model.state_dict(),
      'epochs': epoch
  }, model_path)

print(f'Train was completed successfully')
# Out:
# Training [1/200]: 100%|██████████| 163/163 [00:44<00:00,  3.69it/s]
# Train losses: 1.70300, Train accuracy: 38.44%
# Validation...: 100%|██████████| 8/8 [00:08<00:00,  1.06s/it]
# Model accuracy on testing: 39.68%
# Training [2/200]: 100%|██████████| 163/163 [00:41<00:00,  3.93it/s]
# Train losses: 1.45918, Train accuracy: 47.47%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.39it/s]
# Model accuracy on testing: 43.57%
# Training [3/200]: 100%|██████████| 163/163 [00:41<00:00,  3.94it/s]
# Train losses: 1.32336, Train accuracy: 52.62%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.40it/s]
# Model accuracy on testing: 44.12%
# Training [4/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 1.22826, Train accuracy: 55.54%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.49it/s]
# Model accuracy on testing: 49.75%
# Training [5/200]: 100%|██████████| 163/163 [00:41<00:00,  3.94it/s]
# Train losses: 1.10045, Train accuracy: 60.07%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.44it/s]
# Model accuracy on testing: 47.73%
# Training [6/200]: 100%|██████████| 163/163 [00:42<00:00,  3.81it/s]
# Train losses: 1.04318, Train accuracy: 62.91%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.44it/s]
# Model accuracy on testing: 37.71%
# Training [7/200]: 100%|██████████| 163/163 [00:41<00:00,  3.97it/s]
# Train losses: 1.14527, Train accuracy: 58.98%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.50it/s]
# Model accuracy on testing: 47.84%
# Training [8/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.61540, Train accuracy: 79.33%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.58it/s]
# Model accuracy on testing: 55.56%
# Training [9/200]: 100%|██████████| 163/163 [00:42<00:00,  3.79it/s]
# Train losses: 0.40608, Train accuracy: 86.00%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.49it/s]
# Model accuracy on testing: 53.75%
# Training [10/200]: 100%|██████████| 163/163 [00:41<00:00,  3.97it/s]
# Train losses: 0.29095, Train accuracy: 90.08%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.49it/s]
# Model accuracy on testing: 56.32%
# Training [11/200]: 100%|██████████| 163/163 [00:41<00:00,  3.97it/s]
# Train losses: 0.20725, Train accuracy: 93.52%
# Validation...: 100%|██████████| 8/8 [00:07<00:00,  1.08it/s]
# Model accuracy on testing: 54.24%
# Training [12/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.11689, Train accuracy: 96.46%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.45it/s]
# Model accuracy on testing: 55.83%
# Training [13/200]: 100%|██████████| 163/163 [00:40<00:00,  3.99it/s]
# Train losses: 0.09764, Train accuracy: 98.02%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.46it/s]
# Model accuracy on testing: 54.02%
# Training [14/200]: 100%|██████████| 163/163 [00:43<00:00,  3.78it/s]
# Train losses: 0.04860, Train accuracy: 99.32%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.49it/s]
# Model accuracy on testing: 54.02%
# Training [15/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.04306, Train accuracy: 99.54%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.39it/s]
# Model accuracy on testing: 55.56%
# Training [16/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.03172, Train accuracy: 99.53%
# Validation...: 100%|██████████| 8/8 [00:07<00:00,  1.05it/s]
# Model accuracy on testing: 55.45%
# Training [17/200]: 100%|██████████| 163/163 [00:41<00:00,  3.97it/s]
# Train losses: 0.03663, Train accuracy: 99.59%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.46it/s]
# Model accuracy on testing: 54.02%
# Training [18/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.02927, Train accuracy: 99.70%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.44it/s]
# Model accuracy on testing: 53.75%
# Training [19/200]: 100%|██████████| 163/163 [00:43<00:00,  3.79it/s]
# Train losses: 0.02508, Train accuracy: 99.73%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.46it/s]
# Model accuracy on testing: 55.23%
# Training [20/200]: 100%|██████████| 163/163 [00:41<00:00,  3.97it/s]
# Train losses: 0.02504, Train accuracy: 99.68%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.46it/s]
# Model accuracy on testing: 54.46%
# Training [21/200]: 100%|██████████| 163/163 [00:41<00:00,  3.97it/s]
# Train losses: 0.02565, Train accuracy: 99.66%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.44it/s]
# Model accuracy on testing: 54.52%
# Training [22/200]: 100%|██████████| 163/163 [00:43<00:00,  3.78it/s]
# Train losses: 0.04687, Train accuracy: 99.72%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.49it/s]
# Model accuracy on testing: 54.95%
# Training [23/200]: 100%|██████████| 163/163 [00:40<00:00,  3.99it/s]
# Train losses: 0.05038, Train accuracy: 99.72%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.51it/s]
# Model accuracy on testing: 53.48%
# Training [24/200]: 100%|██████████| 163/163 [00:41<00:00,  3.97it/s]
# Train losses: 0.03973, Train accuracy: 99.71%
# Validation...: 100%|██████████| 8/8 [00:08<00:00,  1.02s/it]
# Model accuracy on testing: 54.13%
# Training [25/200]: 100%|██████████| 163/163 [00:41<00:00,  3.97it/s]
# Train losses: 0.03131, Train accuracy: 99.70%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.47it/s]
# Model accuracy on testing: 54.57%
# Training [26/200]: 100%|██████████| 163/163 [00:40<00:00,  4.04it/s]
# Train losses: 0.04388, Train accuracy: 99.72%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.47it/s]
# Model accuracy on testing: 55.50%
# Training [27/200]: 100%|██████████| 163/163 [00:43<00:00,  3.75it/s]
# Train losses: 0.02591, Train accuracy: 99.73%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.46it/s]
# Model accuracy on testing:
200]: 100%|██████████| 163/163 [00:41<00:00,  3.97it/s]
# Train losses: 0.04071, Train accuracy: 99.80%
# Validation...: 100%|██████████| 8/8 [00:07<00:00,  1.05it/s]
# Model accuracy on testing: 54.41%
# Training [67/200]: 100%|██████████| 163/163 [00:41<00:00,  3.97it/s]
# Train losses: 0.03329, Train accuracy: 99.79%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.51it/s]
# Model accuracy on testing: 55.12%
# Training [68/200]: 100%|██████████| 163/163 [00:41<00:00,  3.97it/s]
# Train losses: 0.02283, Train accuracy: 99.79%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.48it/s]
# Model accuracy on testing: 54.35%
# Training [69/200]: 100%|██████████| 163/163 [00:43<00:00,  3.78it/s]
# Train losses: 0.02553, Train accuracy: 99.81%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.45it/s]
# Model accuracy on testing: 55.17%
# Training [70/200]: 100%|██████████| 163/163 [00:41<00:00,  3.98it/s]
# Train losses: 0.02156, Train accuracy: 99.85%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.47it/s]
# Model accuracy on testing: 54.46%
# Training [71/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.02900, Train accuracy: 99.86%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.48it/s]
# Model accuracy on testing: 54.79%
# Training [72/200]: 100%|██████████| 163/163 [00:43<00:00,  3.75it/s]
# Train losses: 0.02118, Train accuracy: 99.79%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.46it/s]
# Model accuracy on testing: 54.35%
# Training [73/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.01726, Train accuracy: 99.84%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.48it/s]
# Model accuracy on testing: 55.12%
# Training [74/200]: 100%|██████████| 163/163 [00:40<00:00,  3.99it/s]
# Train losses: 0.01993, Train accuracy: 99.82%
# Validation...: 100%|██████████| 8/8 [00:08<00:00,  1.01s/it]
# Model accuracy on testing: 55.99%
# Training [75/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.02479, Train accuracy: 99.87%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.52it/s]
# Model accuracy on testing: 54.79%
# Training [76/200]: 100%|██████████| 163/163 [00:40<00:00,  4.00it/s]
# Train losses: 0.04308, Train accuracy: 99.85%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.50it/s]
# Model accuracy on testing: 54.13%
# Training [77/200]: 100%|██████████| 163/163 [00:43<00:00,  3.74it/s]
# Train losses: 0.02091, Train accuracy: 99.80%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.43it/s]
# Model accuracy on testing: 54.90%
# Training [78/200]: 100%|██████████| 163/163 [00:40<00:00,  4.00it/s]
# Train losses: 0.01821, Train accuracy: 99.80%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.52it/s]
# Model accuracy on testing: 55.61%
# Training [79/200]: 100%|██████████| 163/163 [00:40<00:00,  3.99it/s]
# Train losses: 0.02683, Train accuracy: 99.85%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.46it/s]
# Model accuracy on testing: 53.91%
# Training [80/200]: 100%|██████████| 163/163 [00:43<00:00,  3.72it/s]
# Train losses: 0.01703, Train accuracy: 99.86%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.52it/s]
# Model accuracy on testing: 53.80%
# Training [81/200]: 100%|██████████| 163/163 [00:40<00:00,  3.99it/s]
# Train losses: 0.02988, Train accuracy: 99.82%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.51it/s]
# Model accuracy on testing: 55.83%
# Training [82/200]: 100%|██████████| 163/163 [00:41<00:00,  3.96it/s]
# Train losses: 0.02109, Train accuracy: 99.86%
# Validation...: 100%|██████████| 8/8 [00:08<00:00,  1.03s/it]
# Model accuracy on testing: 54.73%
# Training [83/200]: 100%|██████████| 163/163 [00:41<00:00,  3.97it/s]
# Train losses: 0.02715, Train accuracy: 99.87%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.54it/s]
# Model accuracy on testing: 53.69%
# Training [84/200]: 100%|██████████| 163/163 [00:40<00:00,  4.01it/s]
# Train losses: 0.03577, Train accuracy: 99.85%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.45it/s]
# Model accuracy on testing: 55.45%
# Training [85/200]: 100%|██████████| 163/163 [00:41<00:00,  3.89it/s]
# Train losses: 0.03121, Train accuracy: 99.86%
# Validation...: 100%|██████████| 8/8 [00:07<00:00,  1.12it/s]
# Model accuracy on testing: 54.73%
# Training [86/200]: 100%|██████████| 163/163 [00:41<00:00,  3.95it/s]
# Train losses: 0.04433, Train accuracy: 99.89%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.48it/s]
# Model accuracy on testing: 54.52%
# Training [87/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.02700, Train accuracy: 99.86%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.46it/s]
# Model accuracy on testing: 54.73%
# Training [88/200]: 100%|██████████| 163/163 [00:42<00:00,  3.79it/s]
# Train losses: 0.02731, Train accuracy: 99.86%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.46it/s]
# Model accuracy on testing: 54.19%
# Training [89/200]: 100%|██████████| 163/163 [00:41<00:00,  3.97it/s]
# Train losses: 0.02359, Train accuracy: 99.87%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.44it/s]
# Model accuracy on testing: 53.86%
# Training [90/200]: 100%|██████████| 163/163 [00:41<00:00,  3.97it/s]
# Train losses: 0.01698, Train accuracy: 99.88%
# Validation...: 100%|██████████| 8/8 [00:07<00:00,  1.06it/s]
# Model accuracy on testing: 54.35%
# Training [91/200]: 100%|██████████| 163/163 [00:41<00:00,  3.98it/s]
# Train losses: 0.02110, Train accuracy: 99.86%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.47it/s]
# Model accuracy on testing: 54.35%
# Training [92/200]: 100%|██████████| 163/163 [00:41<00:00,  3.97it/s]
# Train losses: 0.05256, Train accuracy: 99.80%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.46it/s]
# Model accuracy on testing: 53.86%
# Training [93/200]: 100%|██████████| 163/163 [00:43<00:00,  3.78it/s]
# Train losses: 0.03911, Train accuracy: 99.88%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.47it/s]
# Model accuracy on testing: 54.02%
# Training [94/200]: 100%|██████████| 163/163 [00:41<00:00,  3.97it/s]
# Train losses: 0.03319, Train accuracy: 99.87%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.43it/s]
# Model accuracy on testing: 54.57%
# Training [95/200]: 100%|██████████| 163/163 [00:40<00:00,  3.99it/s]
# Train losses: 0.01888, Train accuracy: 99.87%
# Validation...: 100%|██████████| 8/8 [00:07<00:00,  1.03it/s]
# Model accuracy on testing: 54.30%
# Training [96/200]: 100%|██████████| 163/163 [00:41<00:00,  3.95it/s]
# Train losses: 0.02369, Train accuracy: 99.86%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.49it/s]
# Model accuracy on testing: 54.95%
# Training [97/200]: 100%|██████████| 163/163 [00:40<00:00,  3.99it/s]
# Train losses: 0.02587, Train accuracy: 99.83%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.52it/s]
# Model accuracy on testing: 55.88%
# Training [98/200]: 100%|██████████| 163/163 [00:40<00:00,  4.00it/s]
# Train losses: 0.04831, Train accuracy: 99.89%
# Validation...: 100%|██████████| 8/8 [00:08<00:00,  1.01s/it]
# Model accuracy on testing: 55.06%
# Training [99/200]: 100%|██████████| 163/163 [00:40<00:00,  3.99it/s]
# Train losses: 0.02208, Train accuracy: 99.85%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.53it/s]
# Model accuracy on testing: 54.95%
# Training [100/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.01847, Train accuracy: 99.87%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.47it/s]
# Model accuracy on testing: 55.17%
# Training [101/200]: 100%|██████████| 163/163 [00:43<00:00,  3.74it/s]
# Train losses: 0.01756, Train accuracy: 99.88%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.40it/s]
# Model accuracy on testing: 54.35%
# Training [102/200]: 100%|██████████| 163/163 [00:40<00:00,  4.00it/s]
# Train losses: 0.01588, Train accuracy: 99.86%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.50it/s]
# Model accuracy on testing: 54.95%
# Training [103/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.03739, Train accuracy: 99.88%
# Validation...: 100%|██████████| 8/8 [00:08<00:00,  1.03s/it]
# Model accuracy on testing: 55.45%
# Training [104/200]: 100%|██████████| 163/163 [00:41<00:00,  3.97it/s]
# Train losses: 0.02257, Train accuracy: 99.89%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.51it/s]
# Model accuracy on testing: 53.97%
# Training [105/200]: 100%|██████████| 163/163 [00:40<00:00,  4.00it/s]
# Train losses: 0.03688, Train accuracy: 99.88%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.47it/s]
# Model accuracy on testing: 54.79%
# Training [106/200]: 100%|██████████| 163/163 [00:41<00:00,  3.97it/s]
# Train losses: 0.01655, Train accuracy: 99.90%
# Validation...: 100%|██████████| 8/8 [00:08<00:00,  1.03s/it]
# Model accuracy on testing: 54.08%
# Training [107/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.02607, Train accuracy: 99.86%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.55it/s]
# Model accuracy on testing: 53.80%
# Training [108/200]: 100%|██████████| 163/163 [00:40<00:00,  4.00it/s]
# Train losses: 0.02283, Train accuracy: 99.88%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.44it/s]
# Model accuracy on testing: 53.97%
# Training [109/200]: 100%|██████████| 163/163 [00:43<00:00,  3.74it/s]
# Train losses: 0.03893, Train accuracy: 99.89%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.51it/s]
# Model accuracy on testing: 54.57%
# Training [110/200]: 100%|██████████| 163/163 [00:41<00:00,  3.97it/s]
# Train losses: 0.01547, Train accuracy: 99.84%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.47it/s]
# Model accuracy on testing: 54.79%
# Training [111/200]: 100%|██████████| 163/163 [00:40<00:00,  3.99it/s]
# Train losses: 0.03905, Train accuracy: 99.84%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.48it/s]
# Model accuracy on testing: 54.02%
# Training [112/200]: 100%|██████████| 163/163 [00:43<00:00,  3.74it/s]
# Train losses: 0.02140, Train accuracy: 99.88%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.49it/s]
# Model accuracy on testing: 54.84%
# Training [113/200]: 100%|██████████| 163/163 [00:40<00:00,  3.99it/s]
# Train losses: 0.01522, Train accuracy: 99.90%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.46it/s]
# Model accuracy on testing: 54.24%
# Training [114/200]: 100%|██████████| 163/163 [00:40<00:00,  3.99it/s]
# Train losses: 0.02132, Train accuracy: 99.87%
# Validation...: 100%|██████████| 8/8 [00:08<00:00,  1.01s/it]
# Model accuracy on testing: 54.30%
# Training [115/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.02035, Train accuracy: 99.89%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.47it/s]
# Model accuracy on testing: 54.68%
# Training [116/200]: 100%|██████████| 163/163 [00:41<00:00,  3.98it/s]
# Train losses: 0.03201, Train accuracy: 99.94%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.50it/s]
# Model accuracy on testing: 55.01%
# Training [117/200]: 100%|██████████| 163/163 [00:40<00:00,  3.99it/s]
# Train losses: 0.02206, Train accuracy: 99.89%
# Validation...: 100%|██████████| 8/8 [00:08<00:00,  1.01s/it]
# Model accuracy on testing: 55.01%
# Training [118/200]: 100%|██████████| 163/163 [00:41<00:00,  3.97it/s]
# Train losses: 0.02280, Train accuracy: 99.87%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.47it/s]
# Model accuracy on testing: 54.68%
# Training [119/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.02764, Train accuracy: 99.89%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.47it/s]
# Model accuracy on testing: 55.23%
# Training [120/200]: 100%|██████████| 163/163 [00:43<00:00,  3.74it/s]
# Train losses: 0.02123, Train accuracy: 99.89%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.44it/s]
# Model accuracy on testing: 54.24%
# Training [121/200]: 100%|██████████| 163/163 [00:40<00:00,  3.99it/s]
# Train losses: 0.02655, Train accuracy: 99.87%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.49it/s]
# Model accuracy on testing: 54.19%
# Training [122/200]: 100%|██████████| 163/163 [00:41<00:00,  3.97it/s]
# Train losses: 0.02028, Train accuracy: 99.87%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.52it/s]
# Model accuracy on testing: 55.12%
# Training [123/200]: 100%|██████████| 163/163 [00:43<00:00,  3.75it/s]
# Train losses: 0.02562, Train accuracy: 99.92%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.49it/s]
# Model accuracy on testing: 53.64%
# Training [124/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.02047, Train accuracy: 99.90%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.52it/s]
# Model accuracy on testing: 53.59%
# Training [125/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.02213, Train accuracy: 99.89%
# Validation...: 100%|██████████| 8/8 [00:08<00:00,  1.00s/it]
# Model accuracy on testing: 54.19%
# Training [126/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.03492, Train accuracy: 99.91%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.53it/s]
# Model accuracy on testing: 54.46%
# Training [127/200]: 100%|██████████| 163/163 [00:40<00:00,  4.00it/s]
# Train losses: 0.02718, Train accuracy: 99.92%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.55it/s]
# Model accuracy on testing: 54.90%
# Training [128/200]: 100%|██████████| 163/163 [00:41<00:00,  3.93it/s]
# Train losses: 0.01508, Train accuracy: 99.92%
# Validation...: 100%|██████████| 8/8 [00:07<00:00,  1.03it/s]
# Model accuracy on testing: 54.95%
# Training [129/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.04392, Train accuracy: 99.87%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.50it/s]
# Model accuracy on testing: 54.63%
# Training [130/200]: 100%|██████████| 163/163 [00:40<00:00,  3.99it/s]
# Train losses: 0.01961, Train accuracy: 99.87%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.54it/s]
# Model accuracy on testing: 55.34%
# Training [131/200]: 100%|██████████| 163/163 [00:43<00:00,  3.74it/s]
# Train losses: 0.03600, Train accuracy: 99.91%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.47it/s]
# Model accuracy on testing: 54.95%
# Training [132/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.01679, Train accuracy: 99.93%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.48it/s]
# Model accuracy on testing: 54.95%
# Training [133/200]: 100%|██████████| 163/163 [00:41<00:00,  3.97it/s]
# Train losses: 0.02485, Train accuracy: 99.94%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.47it/s]
# Model accuracy on testing: 54.68%
# Training [134/200]: 100%|██████████| 163/163 [00:43<00:00,  3.75it/s]
# Train losses: 0.01437, Train accuracy: 99.88%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.48it/s]
# Model accuracy on testing: 55.72%
# Training [135/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.01689, Train accuracy: 99.94%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.49it/s]
# Model accuracy on testing: 54.57%
# Training [136/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.03137, Train accuracy: 99.88%
# Validation...: 100%|██████████| 8/8 [00:07<00:00,  1.02it/s]
# Model accuracy on testing: 54.52%
# Training [137/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.02951, Train accuracy: 99.89%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.50it/s]
# Model accuracy on testing: 54.73%
# Training [138/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.03038, Train accuracy: 99.89%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.53it/s]
# Model accuracy on testing: 55.50%
# Training [139/200]: 100%|██████████| 163/163 [00:41<00:00,  3.97it/s]
# Train losses: 0.01843, Train accuracy: 99.90%
# Validation...: 100%|██████████| 8/8 [00:07<00:00,  1.00it/s]
# Model accuracy on testing: 54.73%
# Training [140/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.05017, Train accuracy: 99.92%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.47it/s]
# Model accuracy on testing: 54.41%
# Training [141/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.04311, Train accuracy: 99.88%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.51it/s]
# Model accuracy on testing: 54.24%
# Training [142/200]: 100%|██████████| 163/163 [00:43<00:00,  3.75it/s]
# Train losses: 0.01581, Train accuracy: 99.93%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.47it/s]
# Model accuracy on testing: 54.02%
# Training [143/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.02249, Train accuracy: 99.93%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.50it/s]
# Model accuracy on testing: 53.80%
# Training [144/200]: 100%|██████████| 163/163 [00:40<00:00,  3.99it/s]
# Train losses: 0.01432, Train accuracy: 99.91%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.48it/s]
# Model accuracy on testing: 54.63%
# Training [145/200]: 100%|██████████| 163/163 [00:43<00:00,  3.72it/s]
# Train losses: 0.03074, Train accuracy: 99.90%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.45it/s]
# Model accuracy on testing: 54.90%
# Training [146/200]: 100%|██████████| 163/163 [00:40<00:00,  3.99it/s]
# Train losses: 0.02016, Train accuracy: 99.91%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.52it/s]
# Model accuracy on testing: 54.08%
# Training [147/200]: 100%|██████████| 163/163 [00:41<00:00,  3.96it/s]
# Train losses: 0.02402, Train accuracy: 99.92%
# Validation...: 100%|██████████| 8/8 [00:07<00:00,  1.02it/s]
# Model accuracy on testing: 55.34%
# Training [148/200]: 100%|██████████| 163/163 [00:41<00:00,  3.96it/s]
# Train losses: 0.03882, Train accuracy: 99.91%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.47it/s]
# Model accuracy on testing: 55.06%
# Training [149/200]: 100%|██████████| 163/163 [00:40<00:00,  4.00it/s]
# Train losses: 0.01327, Train accuracy: 99.87%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.52it/s]
# Model accuracy on testing: 53.75%
# Training [150/200]: 100%|██████████| 163/163 [00:41<00:00,  3.96it/s]
# Train losses: 0.01553, Train accuracy: 99.91%
# Validation...: 100%|██████████| 8/8 [00:08<00:00,  1.04s/it]
# Model accuracy on testing: 54.19%
# Training [151/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.02327, Train accuracy: 99.90%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.53it/s]
# Model accuracy on testing: 53.69%
# Training [152/200]: 100%|██████████| 163/163 [00:40<00:00,  4.01it/s]
# Train losses: 0.03044, Train accuracy: 99.86%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.52it/s]
# Model accuracy on testing: 55.06%
# Training [153/200]: 100%|██████████| 163/163 [00:43<00:00,  3.71it/s]
# Train losses: 0.01728, Train accuracy: 99.90%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.45it/s]
# Model accuracy on testing: 54.52%
# Training [154/200]: 100%|██████████| 163/163 [00:40<00:00,  4.00it/s]
# Train losses: 0.01612, Train accuracy: 99.91%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.52it/s]
# Model accuracy on testing: 54.41%
# Training [155/200]: 100%|██████████| 163/163 [00:40<00:00,  3.99it/s]
# Train losses: 0.01829, Train accuracy: 99.88%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.46it/s]
# Model accuracy on testing: 54.73%
# Training [156/200]: 100%|██████████| 163/163 [00:44<00:00,  3.70it/s]
# Train losses: 0.02032, Train accuracy: 99.93%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.54it/s]
# Model accuracy on testing: 54.13%
# Training [157/200]: 100%|██████████| 163/163 [00:40<00:00,  4.00it/s]
# Train losses: 0.04782, Train accuracy: 99.90%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.52it/s]
# Model accuracy on testing: 54.68%
# Training [158/200]: 100%|██████████| 163/163 [00:41<00:00,  3.91it/s]
# Train losses: 0.03998, Train accuracy: 99.88%
# Validation...: 100%|██████████| 8/8 [00:07<00:00,  1.06it/s]
# Model accuracy on testing: 54.57%
# Training [159/200]: 100%|██████████| 163/163 [00:40<00:00,  3.98it/s]
# Train losses: 0.01597, Train accuracy: 99.89%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.48it/s]
# Model accuracy on testing: 54.30%
# Training [160/200]: 100%|██████████| 163/163 [00:41<00:00,  3.94it/s]
# Train losses: 0.03617, Train accuracy: 99.91%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.44it/s]
# Model accuracy on testing: 55.28%
# Training [161/200]: 100%|██████████| 163/163 [00:42<00:00,  3.80it/s]
# Train losses: 0.01210, Train accuracy: 99.89%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.45it/s]
# Model accuracy on testing: 55.23%
# Training [162/200]: 100%|██████████| 163/163 [00:40<00:00,  3.99it/s]
# Train losses: 0.03841, Train accuracy: 99.90%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.46it/s]
# Model accuracy on testing: 55.06%
# Training [163/200]: 100%|██████████| 163/163 [00:41<00:00,  3.97it/s]
# Train losses: 0.01431, Train accuracy: 99.94%
# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.44it/s]
# Model accuracy on testing:

# Validation...: 100%|██████████| 8/8 [00:05<00:00,  1.46it/s]
# Model accuracy on testing: 53.91%
#
# Train was completed successfully

# %% [markdown]
# ## Model evaluation

# %%
correct, total = 0, 0
model.eval()

for images, targets in tqdm(test_loader, desc=f'Validation...'):
  images, targets = images.to(device), targets.to(device)

  with torch.no_grad():
    outputs = model(images)
    predictions = torch.argmax(outputs, dim=1)
  total += targets.size(0)
  correct += sum(predictions == targets).item()
acc = 100.0 * correct / total
print(f'Model accuracy on testing: {acc:.2f}')
# Out:
# Validation...: 100%|██████████| 8/8 [00:06<00:00,  1.20it/s]
# Model accuracy on testing: 53.91

# %% [markdown]
# ## Load model & inference

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
model_path = '/home/labuser/Joy/emotion-recognition/src/models/resnet-last-model.pth'
# model_path = '/content/drive/MyDrive/emotion-recognition/models/resnet-best-full.pth'
checkpoint = torch.load(model_path, map_location=device)
classes = checkpoint['classes']
model_state_dict = checkpoint['model_state_dict']

model = ResNet(len(classes)).to(device)
model.load_state_dict(model_state_dict)
checkpoint['epochs']
# Out:
# 199

# %%
from PIL import Image
from torchvision.transforms import v2 as T

# %%
# Infer the model
def predict(image_path, model):
  image = Image.open(image_path).convert('RGB')
  transforms = T.Compose([
      T.ToImage(),
      T.ToDtype(torch.float32, scale=True)
  ])
  image = transforms(image).to(device)

  model.eval()
  with torch.no_grad():
    outputs = model(image.unsqueeze(0))
  predictions = torch.argmax(outputs, dim=1)
  return predictions

# %%
image_path = '/content/face.jpg'
results = predict(image_path, model)
classes[results.item()]
# Out:
# 'happy'

# %%
def predict_with(image_path, model, classes):
  image = Image.open(image_path).convert('RGB')
  # transforms = T.Compose([
  #     T.ToImage(),
  #     T.ToDtype(torch.float32, scale=True),
  #     T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
  # ])

  transforms = ResNet18_Weights.IMAGENET1K_V1.transforms()
  image_batch = transforms(image).to(device).unsqueeze(0)

  model.eval()
  with torch.no_grad():
    outputs = model(image_batch)
  probabilities = F.softmax(outputs[0], dim=0)
  values, id = torch.topk(probabilities, 5)

  pred = {}
  for value, id in zip(values, id):
    pred[classes[id]] = value.item()
  return pred

# %%
# Neutral
image_path = '/content/drive/MyDrive/emotion-recognition/assets/face.jpg'
predict_with(image_path, model, classes)
# Out:
# {'neutral': 0.99979168176651,
#  'surprise': 0.00011066641309298575,
#  'confused': 4.494014865485951e-05,
#  'angry': 2.68292824330274e-05,
#  'happy': 1.7674638002063148e-05}

# %%
# Neutral
image_path = '/content/drive/MyDrive/emotion-recognition/assets/face1.jpg'
predict_with(image_path, model, classes)
# Out:
# {'neutral': 0.9999744892120361,
#  'confused': 1.795478237909265e-05,
#  'surprise': 6.091743671277072e-06,
#  'sad': 1.3594773236036417e-06,
#  'disgust': 9.24924279388506e-08}

# %%
# Sad
image_path = '/content/drive/MyDrive/emotion-recognition/assets/Screenshot 2025-11-12 004551.png'
predict_with(image_path, model, classes)
# Out:
# {'sad': 0.6969957947731018,
#  'neutral': 0.15038418769836426,
#  'confused': 0.07768415659666061,
#  'angry': 0.05305913835763931,
#  'disgust': 0.01241245400160551}

# %%
# Happy
image_path = '/content/drive/MyDrive/emotion-recognition/assets/Screenshot 2025-11-12 004909.png'
predict_with(image_path, model, classes)
# Out:
# {'neutral': 0.9997139573097229,
#  'sad': 0.0002165273472201079,
#  'surprise': 4.868244650424458e-05,
#  'angry': 8.166888619598467e-06,
#  'shy': 5.029511612519855e-06}
