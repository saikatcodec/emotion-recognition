# %%
# !unzip '/home/labuser/Joy/emotion-recognition/datasets/emotion detection.zip' -d '/home/labuser/Joy/emotion-recognition/datasets/emotion'

# %%
import torch
from torch import nn
from torchvision.models.resnet import resnet50, ResNet50_Weights
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torchvision.transforms.v2 as T
from tqdm import tqdm
from torch import optim
from torch.nn import functional as F
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

# %% [markdown]
# ## Prepare Dataloader

# %%
transforms = ResNet50_Weights.IMAGENET1K_V1.transforms()
transforms
# Out:
# ImageClassification(
#     crop_size=[224]
#     resize_size=[256]
#     mean=[0.485, 0.456, 0.406]
#     std=[0.229, 0.224, 0.225]
#     interpolation=InterpolationMode.BILINEAR
# )

# %%
train_dir = '/home/labuser/Joy/emotion-recognition/datasets/emotion/train'
test_dir = '/home/labuser/Joy/emotion-recognition/datasets/emotion/valid'

# For train
train_dataset = ImageFolder(train_dir, transforms)
train_loader = DataLoader(
    train_dataset,
    batch_size=128,
    shuffle=True,
    pin_memory=True,
    persistent_workers=True,
    num_workers=2
)

# For test
test_dataset = ImageFolder(test_dir, transforms)
test_loader = DataLoader(
    test_dataset,
    batch_size=256,
    shuffle=False,
    pin_memory=True,
    persistent_workers=True,
    num_workers=1
)

# %% [markdown]
# ## Prepare Model

# %%
class ResNet(nn.Module):
  def __init__(self, num_classes):
    super().__init__()

    self.model = resnet50(weights=ResNet50_Weights.IMAGENET1K_V1)

    # Freeze first 20th the layer
    for param in list(self.model.parameters())[:10]:
      param.requires_grad = False

    # Freeze the layer
    for param in list(self.model.parameters())[50:60]:
      param.requires_grad = False

    ## Modify the classification layer
    in_features = self.model.fc.in_features
    self.model.fc = nn.Sequential(
      nn.Dropout(0.5, inplace=True),
      nn.Linear(in_features, num_classes)
    )

  def forward(self, x):
    x = self.model(x)
    return x

# %% [markdown]
# ## Loss function and optimizers

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
train_dataset.classes
# Out:
# ['angry', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
num_classes = len(train_dataset.classes)
model = ResNet(num_classes).to(device)

# %%
# Calculate class weight
labels = np.array(train_dataset.targets)
class_weight = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(labels),
    y=labels
)

class_weight = torch.tensor(class_weight, device=device, dtype=torch.float32)
class_weight
# Out:
# tensor([0.9229, 1.0859, 1.3407, 0.9677, 1.0669, 0.7818], device='cuda:0')

# %%
# Loss function & optimizer
criterion = nn.CrossEntropyLoss(weight=class_weight)
params = [param for param in model.parameters() if param.requires_grad]
optimizer = optim.Adam(params, lr=0.001, weight_decay=1e-4)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='max',
    factor=0.1,
    patience=2,
    threshold=0.01,
    cooldown=1,
    min_lr=1e-6
)

# %% [markdown]
# ## Training Loop

# %%
epochs = 100
min_acc = 0

for epoch in range(epochs):
  model.train()
  running_loss = 0.0
  correct_t, total_t = 0, 0

  for images, targets in tqdm(train_loader, desc=f'Training [{epoch + 1}/{epochs}]: '):
    images, targets = images.to(device), targets.to(device)

    optimizer.zero_grad()
    outputs = model(images)
    losses = criterion(outputs, targets)
    losses.backward()
    optimizer.step()

    pred = torch.argmax(outputs, dim=1)
    correct_t += (targets == pred).sum().item()
    total_t += targets.size(0)
    running_loss += losses.item()
  t_loss = running_loss / len(train_loader)
  t_acc = 100 * correct_t / total_t
  print(f'Train losses: {t_loss:.5f}, Train accuracy: {t_acc:.2f}%')

  ## Validation test
  correct_e, total_e = 0, 0
  model.eval()

  for images, targets in tqdm(test_loader, desc='Validation...'):
    images, targets = images.to(device), targets.to(device)

    with torch.no_grad():
      outputs = model(images)
      predictions = torch.argmax(outputs, dim=1)
    total_e += targets.size(0)
    correct_e += sum(predictions == targets).item()
  acc = 100.0 * correct_e / total_e
  scheduler.step(acc)
  print(f'Recent learning rate: {scheduler.get_last_lr()}')
  print(f'Model accuracy on testing: {acc:.2f}%\n')

  # Save best model
  if (acc > min_acc):
    best_model = f'/home/labuser/Joy/emotion-recognition/src/models/resnet-best-full.pth'
    torch.save({
        'classes': train_dataset.classes,
        'model_state_dict': model.state_dict(),
        'epochs': epoch
    }, best_model)
    min_acc = acc
  
  # Save the last model
  model_path = f'/home/labuser/Joy/emotion-recognition/src/models/resnet-last-model.pth'
  torch.save({
      'classes': train_dataset.classes,
      'model_state_dict': model.state_dict(),
      'epochs': epoch
  }, model_path)

print(f'Train was completed successfully')
# Out:
# Training [1/100]: 100%|██████████| 115/115 [00:31<00:00,  3.71it/s]
# Train losses: 1.28542, Train accuracy: 47.41%
# Validation...: 100%|██████████| 6/6 [00:06<00:00,  1.00s/it]
# Recent learning rate: [0.001]
# Model accuracy on testing: 51.82%
# Training [2/100]: 100%|██████████| 115/115 [00:28<00:00,  4.04it/s]
# Train losses: 1.06826, Train accuracy: 58.05%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.58it/s]
# Recent learning rate: [0.001]
# Model accuracy on testing: 62.06%
# Training [3/100]: 100%|██████████| 115/115 [00:28<00:00,  3.99it/s]
# Train losses: 0.97153, Train accuracy: 62.34%
# Validation...: 100%|██████████| 6/6 [00:04<00:00,  1.47it/s]
# Recent learning rate: [0.001]
# Model accuracy on testing: 56.87%
# Training [4/100]: 100%|██████████| 115/115 [00:28<00:00,  3.99it/s]
# Train losses: 0.82514, Train accuracy: 68.00%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.54it/s]
# Recent learning rate: [0.001]
# Model accuracy on testing: 55.82%
# Training [5/100]: 100%|██████████| 115/115 [00:28<00:00,  3.99it/s]
# Train losses: 0.72019, Train accuracy: 72.59%
# Validation...: 100%|██████████| 6/6 [00:04<00:00,  1.47it/s]
# Recent learning rate: [0.0001]
# Model accuracy on testing: 49.37%
# Training [6/100]: 100%|██████████| 115/115 [00:28<00:00,  3.97it/s]
# Train losses: 0.38592, Train accuracy: 86.04%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.64it/s]
# Recent learning rate: [0.0001]
# Model accuracy on testing: 65.85%
# Training [7/100]: 100%|██████████| 115/115 [00:28<00:00,  3.98it/s]
# Train losses: 0.20152, Train accuracy: 92.84%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.60it/s]
# Recent learning rate: [0.0001]
# Model accuracy on testing: 65.57%
# Training [8/100]: 100%|██████████| 115/115 [00:28<00:00,  3.98it/s]
# Train losses: 0.09938, Train accuracy: 96.89%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.60it/s]
# Recent learning rate: [0.0001]
# Model accuracy on testing: 66.83%
# Training [9/100]: 100%|██████████| 115/115 [00:28<00:00,  4.01it/s]
# Train losses: 0.05689, Train accuracy: 98.59%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.57it/s]
# Recent learning rate: [0.0001]
# Model accuracy on testing: 66.69%
# Training [10/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.05039, Train accuracy: 98.65%
# Validation...: 100%|██████████| 6/6 [00:04<00:00,  1.48it/s]
# Recent learning rate: [0.0001]
# Model accuracy on testing: 64.80%
# Training [11/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.03447, Train accuracy: 99.08%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.58it/s]
# Recent learning rate: [1e-05]
# Model accuracy on testing: 63.25%
# Training [12/100]: 100%|██████████| 115/115 [00:28<00:00,  4.07it/s]
# Train losses: 0.01226, Train accuracy: 99.86%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.63it/s]
# Recent learning rate: [1e-05]
# Model accuracy on testing: 65.36%
# Training [13/100]: 100%|██████████| 115/115 [00:28<00:00,  4.07it/s]
# Train losses: 0.01014, Train accuracy: 99.89%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.58it/s]
# Recent learning rate: [1e-05]
# Model accuracy on testing: 64.03%
# Training [14/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00814, Train accuracy: 99.95%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.56it/s]
# Recent learning rate: [1e-05]
# Model accuracy on testing: 65.50%
# Training [15/100]: 100%|██████████| 115/115 [00:28<00:00,  4.07it/s]
# Train losses: 0.00837, Train accuracy: 99.94%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.56it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 64.73%
# Training [16/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00697, Train accuracy: 99.95%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.58it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 66.06%
# Training [17/100]: 100%|██████████| 115/115 [00:28<00:00,  4.06it/s]
# Train losses: 0.00641, Train accuracy: 99.97%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.55it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.36%
# Training [18/100]: 100%|██████████| 115/115 [00:28<00:00,  4.06it/s]
# Train losses: 0.00702, Train accuracy: 99.97%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.58it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 64.66%
# Training [19/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00704, Train accuracy: 99.97%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.64it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.01%
# Training [20/100]: 100%|██████████| 115/115 [00:28<00:00,  4.07it/s]
# Train losses: 0.00616, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.61it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.36%
# Training [21/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00655, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.63it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.57%
# Training [22/100]: 100%|██████████| 115/115 [00:28<00:00,  4.07it/s]
# Train losses: 0.00659, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.57it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 64.73%
# Training [23/100]: 100%|██████████| 115/115 [00:28<00:00,  4.07it/s]
# Train losses: 0.00662, Train accuracy: 99.97%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.56it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.78%
# Training [24/100]: 100%|██████████| 115/115 [00:28<00:00,  4.07it/s]
# Train losses: 0.00592, Train accuracy: 99.97%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.59it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 64.45%
# Training [25/100]: 100%|██████████| 115/115 [00:28<00:00,  4.07it/s]
# Train losses: 0.00795, Train accuracy: 99.95%
# Validation...: 100%|██████████| 6/6 [00:05<00:00,  1.15it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.22%
# Training [26/100]: 100%|██████████| 115/115 [00:26<00:00,  4.29it/s]
# Train losses: 0.00711, Train accuracy: 99.96%
# Validation...: 100%|██████████| 6/6 [00:05<00:00,  1.15it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.85%
# Training [27/100]: 100%|██████████| 115/115 [00:26<00:00,  4.30it/s]
# Train losses: 0.00937, Train accuracy: 99.96%
# Validation...: 100%|██████████| 6/6 [00:05<00:00,  1.13it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.29%
# Training [28/100]: 100%|██████████| 115/115 [00:26<00:00,  4.30it/s]
# Train losses: 0.00570, Train accuracy: 99.98%
# Validation...: 100%|██████████| 6/6 [00:05<00:00,  1.18it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.08%
# Training [29/100]: 100%|██████████| 115/115 [00:26<00:00,  4.31it/s]
# Train losses: 0.01027, Train accuracy: 99.96%
# Validation...: 100%|██████████| 6/6 [00:05<00:00,  1.13it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.85%
# Training [30/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00593, Train accuracy: 99.96%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.55it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.50%
# Training [31/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00873, Train accuracy: 99.97%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.59it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.29%
# Training [32/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00593, Train accuracy: 99.97%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.61it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 64.31%
# Training [33/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00591, Train accuracy: 99.97%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.64it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 64.94%
# Training [34/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00584, Train accuracy: 99.97%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.53it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 64.66%
# Training [35/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00540, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.57it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.43%
# Training [36/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00484, Train accuracy: 100.00%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.55it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.29%
# Training [37/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00527, Train accuracy: 99.97%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.60it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.08%
# Training [38/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00682, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.61it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.36%
# Training [39/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00445, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.51it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.15%
# Training [40/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00757, Train accuracy: 99.98%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.60it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.08%
# Training [41/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00592, Train accuracy: 99.97%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.55it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 66.06%
# Training [42/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00496, Train accuracy: 99.98%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.58it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.01%
# Training [43/100]: 100%|██████████| 115/115 [00:28<00:00,  4.06it/s]
# Train losses: 0.00773, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.56it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.78%
# Training [44/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00477, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.62it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 64.66%
# Training [45/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00472, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.60it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.57%
# Training [46/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00508, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.56it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.01%
# Training [47/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00514, Train accuracy: 99.97%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.56it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.15%
# Training [48/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00501, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.56it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.29%
# Training [49/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00447, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.55it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.43%
# Training [50/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00615, Train accuracy: 99.97%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.60it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 64.38%
# Training [51/100]: 100%|██████████| 115/115 [00:28<00:00,  4.07it/s]
# Train losses: 0.00441, Train accuracy: 100.00%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.51it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 64.87%
# Training [52/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00444, Train accuracy: 99.97%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.61it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.85%
# Training [53/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00552, Train accuracy: 99.98%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.51it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.08%
# Training [54/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00466, Train accuracy: 99.98%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.58it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.50%
# Training [55/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00406, Train accuracy: 100.00%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.59it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.01%
# Training [56/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00428, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.58it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.36%
# Training [57/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00437, Train accuracy: 100.00%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.56it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.15%
# Training [58/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00427, Train accuracy: 100.00%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.56it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.64%
# Training [59/100]: 100%|██████████| 115/115 [00:28<00:00,  4.07it/s]
# Train losses: 0.01217, Train accuracy: 99.95%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.60it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 64.80%
# Training [60/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00412, Train accuracy: 100.00%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.57it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.57%
# Training [61/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00530, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.52it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.15%
# Training [62/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00486, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.54it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.43%
# Training [63/100]: 100%|██████████| 115/115 [00:28<00:00,  4.07it/s]
# Train losses: 0.00625, Train accuracy: 99.97%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.57it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.08%
# Training [64/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00459, Train accuracy: 99.98%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.55it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 64.10%
# Training [65/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00381, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:04<00:00,  1.32it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.50%
# Training [66/100]: 100%|██████████| 115/115 [00:26<00:00,  4.32it/s]
# Train losses: 0.00416, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:05<00:00,  1.14it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 64.94%
# Training [67/100]: 100%|██████████| 115/115 [00:26<00:00,  4.31it/s]
# Train losses: 0.00491, Train accuracy: 99.98%
# Validation...: 100%|██████████| 6/6 [00:05<00:00,  1.11it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.29%
# Training [68/100]: 100%|██████████| 115/115 [00:26<00:00,  4.32it/s]
# Train losses: 0.00654, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:05<00:00,  1.07it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 64.80%
# Training [69/100]: 100%|██████████| 115/115 [00:26<00:00,  4.32it/s]
# Train losses: 0.00454, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:05<00:00,  1.10it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.08%
# Training [70/100]: 100%|██████████| 115/115 [00:27<00:00,  4.21it/s]
# Train losses: 0.00418, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:04<00:00,  1.24it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.50%
# Training [71/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00497, Train accuracy: 99.98%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.56it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.08%
# Training [72/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00331, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.60it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.08%
# Training [73/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00334, Train accuracy: 100.00%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.56it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.64%
# Training [74/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00325, Train accuracy: 100.00%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.54it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.43%
# Training [75/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00336, Train accuracy: 100.00%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.51it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.78%
# Training [76/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00573, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.57it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.08%
# Training [77/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00363, Train accuracy: 100.00%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.52it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.08%
# Training [78/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00799, Train accuracy: 99.98%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.57it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.22%
# Training [79/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00342, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.60it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 64.73%
# Training [80/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00374, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.63it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 64.73%
# Training [81/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00396, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.62it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.92%
# Training [82/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00363, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.62it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 64.66%
# Training [83/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00330, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.58it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 64.94%
# Training [84/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00412, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.58it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 64.59%
# Training [85/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00368, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.56it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.15%
# Training [86/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00287, Train accuracy: 100.00%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.55it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.22%
# Training [87/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00369, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.56it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 64.87%
# Training [88/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00317, Train accuracy: 100.00%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.55it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.15%
# Training [89/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00293, Train accuracy: 100.00%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.58it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.08%
# Training [90/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00432, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.58it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 64.87%
# Training [91/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00301, Train accuracy: 100.00%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.61it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.36%
# Training [92/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00352, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.57it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.08%
# Training [93/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00599, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.55it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.29%
# Training [94/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00349, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.54it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.36%
# Training [95/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00487, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.56it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 64.38%
# Training [96/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00299, Train accuracy: 100.00%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.60it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.22%
# Training [97/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00345, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:04<00:00,  1.50it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 64.80%
# Training [98/100]: 100%|██████████| 115/115 [00:28<00:00,  4.09it/s]
# Train losses: 0.00308, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.61it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 64.59%
# Training [99/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00350, Train accuracy: 99.99%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.54it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 65.29%
# Training [100/100]: 100%|██████████| 115/115 [00:28<00:00,  4.08it/s]
# Train losses: 0.00798, Train accuracy: 99.97%
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.59it/s]
# Recent learning rate: [1.0000000000000002e-06]
# Model accuracy on testing: 64.45%
#
# Train was completed successfully

# %% [markdown]
# ## Model evaluation

# %%
correct, total = 0, 0
model.eval()

for images, targets in tqdm(test_loader, desc=f'Validation...'):
  images, targets = images.to(device), targets.to(device)

  with torch.no_grad():
    outputs = model(images)
    predictions = torch.argmax(outputs, dim=1)
  total += targets.size(0)
  correct += sum(predictions == targets).item()
acc = 100.0 * correct / total
print(f'Model accuracy on testing: {acc:.2f}')
# Out:
# Validation...: 100%|██████████| 6/6 [00:03<00:00,  1.51it/s]
# Model accuracy on testing: 66.83

# %% [markdown]
# ## Load model & inference

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
# model_path = '/home/labuser/Joy/emotion-recognition/src/models/resnet-last-model.pth'
model_path = '/home/labuser/Joy/emotion-recognition/src/models/resnet-best-full.pth'
checkpoint = torch.load(model_path, map_location=device)
classes = checkpoint['classes']
model_state_dict = checkpoint['model_state_dict']

model = ResNet(len(classes)).to(device)
model.load_state_dict(model_state_dict)
checkpoint['epochs']
# Out:
# 7

# %%
from PIL import Image
from torchvision.transforms import v2 as T

# %%
# Infer the model
def predict(image_path, model):
  image = Image.open(image_path).convert('RGB')
  transforms = T.Compose([
      T.ToImage(),
      T.ToDtype(torch.float32, scale=True)
  ])
  image = transforms(image).to(device)

  model.eval()
  with torch.no_grad():
    outputs = model(image.unsqueeze(0))
  predictions = torch.argmax(outputs, dim=1)
  return predictions

# %%
image_path = '/content/face.jpg'
results = predict(image_path, model)
classes[results.item()]
# Out:
# 'happy'

# %%
def predict_with(image_path, model, classes):
  image = Image.open(image_path).convert('RGB')
  # transforms = T.Compose([
  #     T.ToImage(),
  #     T.ToDtype(torch.float32, scale=True),
  #     T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
  # ])

  transforms = ResNet18_Weights.IMAGENET1K_V1.transforms()
  image_batch = transforms(image).to(device).unsqueeze(0)

  model.eval()
  with torch.no_grad():
    outputs = model(image_batch)
  probabilities = F.softmax(outputs[0], dim=0)
  values, id = torch.topk(probabilities, 5)

  pred = {}
  for value, id in zip(values, id):
    pred[classes[id]] = value.item()
  return pred

# %%
# Neutral
image_path = '/content/drive/MyDrive/emotion-recognition/assets/face.jpg'
predict_with(image_path, model, classes)
# Out:
# {'neutral': 0.99979168176651,
#  'surprise': 0.00011066641309298575,
#  'confused': 4.494014865485951e-05,
#  'angry': 2.68292824330274e-05,
#  'happy': 1.7674638002063148e-05}

# %%
# Neutral
image_path = '/content/drive/MyDrive/emotion-recognition/assets/face1.jpg'
predict_with(image_path, model, classes)
# Out:
# {'neutral': 0.9999744892120361,
#  'confused': 1.795478237909265e-05,
#  'surprise': 6.091743671277072e-06,
#  'sad': 1.3594773236036417e-06,
#  'disgust': 9.24924279388506e-08}

# %%
# Sad
image_path = '/content/drive/MyDrive/emotion-recognition/assets/Screenshot 2025-11-12 004551.png'
predict_with(image_path, model, classes)
# Out:
# {'sad': 0.6969957947731018,
#  'neutral': 0.15038418769836426,
#  'confused': 0.07768415659666061,
#  'angry': 0.05305913835763931,
#  'disgust': 0.01241245400160551}

# %%
# Happy
image_path = '/content/drive/MyDrive/emotion-recognition/assets/Screenshot 2025-11-12 004909.png'
predict_with(image_path, model, classes)
# Out:
# {'neutral': 0.9997139573097229,
#  'sad': 0.0002165273472201079,
#  'surprise': 4.868244650424458e-05,
#  'angry': 8.166888619598467e-06,
#  'shy': 5.029511612519855e-06}
